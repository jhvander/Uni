# %% [markdown]
# # Monte Carlo

# %%
import numpy as np 
import pandas as pd 
from scipy.stats import norm # normal distribution

# graphing
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_theme()
plt.rcParams.update({"text.usetex": True})

# reload our modules constantly (in case we make change)
# %load_ext autoreload
# %autoreload 2

# user 
import w8_probit_ante as probit
import w8_logit_ante as logit
import w8_estimation as est

# %% [markdown]
# # Running a single Monte Carlo step

# %%
model = probit
t = 0.1 * np.ones((3,))
Y, X = model.sim_data(t, 100000)
t0 = model.starting_values(Y, X)
r = est.estimate(model.q, t0, Y, X)
pd.DataFrame({'t0': t, 'theta': r['theta'], 'se': r['se']})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.683393
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
#     t0     theta        se
# 0  0.1  0.099745  0.003986
# 1  0.1  0.101925  0.004008
# 2  0.1  0.105076  0.004010

# %% [markdown]
# # Automating it

# %%
# %%time 
np.random.seed(1337) # so we get the same picture always 
K=2
t = .1 * np.ones((K,))
tab = est.monte_carlo(logit, t, N=100, R=1000)
# Out:
# CPU times: user 4.27 s, sys: 46.9 ms, total: 4.32 s
# Wall time: 2.18 s

# %%
mc_std = tab.groupby('k').theta.std().values
mc_std
# Out:
# array([0.20076106, 0.21170146])

# %%
plt.rcParams.update({"text.usetex": False, 'figure.figsize': (8, 4)})
fig, axes = plt.subplots(K);
for k, t_ in enumerate(t): 
    ax = axes[k]
    tab[tab.k == k].hist('theta', bins=25, ax=ax, density=True, label='$\hat{\\theta}_k$')
    
    ymin, ymax = ax.get_ylim()
    xmin, xmax = ax.get_xlim()
    ax.axvline(t_, ymin=ymin, ymax=ymax, linestyle='--', color='r', label='True value')
    
    xx = np.linspace(xmin, xmax, 100)
    ax.plot(xx, norm.pdf(xx, loc=t_, scale=mc_std[k]), label='$N(\\theta_k^o, \\sigma_{MC}^2)$')
    
    ax.legend()
    ax.set_title(f'$k = {k}$')

plt.tight_layout()
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\h'
# <>:5: SyntaxWarning: invalid escape sequence '\h'
# /var/folders/dm/v2ztg7hn3_z54xvh868kqz300000gn/T/ipykernel_62999/1825417028.py:5: SyntaxWarning: invalid escape sequence '\h'
#   tab[tab.k == k].hist('theta', bins=25, ax=ax, density=True, label='$\hat{\\theta}_k$')
